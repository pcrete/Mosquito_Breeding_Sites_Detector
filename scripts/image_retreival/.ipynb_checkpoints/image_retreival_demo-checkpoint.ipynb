# %% [markdown]
# # Data Collection process
#
# This has been worked on Thailand

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import polygon_to_points
import get_village_points
import GSV_loader
import json
import os
import sys
from IPython.display import Image
# %matplotlib inline

os.chdir("..")
print(os.getcwd())

province = 'กระบี่'.decode('utf8')
district = 'เมือง'.decode('utf8')
subdist = 'ไสไทย'.decode('utf8')
village = 'บ้านไสไทย'.decode('utf8')
# Out:
# /home/poom/breeding_site_detection/scripts

# %% [markdown]
# #### Example of GeoJSON structure
# ```json
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [99.06856570381986, 7.214135468572895],
#                         ...
#                         [99.06804516861584, 7.214268408755317]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "properties": {
#                 "AP_EN": "Ko Lanta",
#                 "AP_IDN": "8103",
#                 "AP_TN": "เกาะลันตา",
#                 "PV_EN": "Krabi",
#                 "PV_IDN": "81",
#                 "PV_TN": "กระบี่",
#                 "TB_EN": "Ko Lanta Yai",
#                 "TB_IDN": "810301",
#                 "TB_TN": "เกาะลันตาใหญ่"
#             },
#             "type": "Feature"
#         }
#     ]
# }
# ```

# %% [markdown]
# ## polygon_to_points
#
# ```python
# get_polygon(province, district, subdist)
# ```

# %%
polygon = polygon_to_points.get_polygon(province, district, subdist)
# Out:
# Imported กระบี่'s GeoJSON
# loaded polygon

# %%
polygon

# %%
points = polygon_to_points.extract_coordinates(polygon)
# Out:
# Iterating through roads:   0%|          | 0/230 [00:00<?, ?it/s]
# retrieved roads (linestrngs) from overpass api
# converting linestrings to coordinates..
# Iterating through roads: 100%|██████████| 230/230 [00:23<00:00,  9.77it/s]
# linestring: 230 lines
# total points: 2256points

# %% [markdown]
# ### Latitude Longitude

# %%
points[:5]
# Out:
# [[8.046752177594023, 98.90769175011755],
#  [8.047062455188044, 98.9080177001351],
#  [8.04749577999848, 98.90829157003455],
#  [8.04788445999696, 98.90851853996911],
#  [8.049136335998542, 98.90805435698174]]

# %% [markdown]
# ## get_village_points

# %%
village_list = get_village_points.get_village_lists(province, district, subdist, village)

# %%
village_list[:2]
# Out:
# [{'Coordinate': [98.87320411378114, 8.108529027401074],
#   'Village': u'\u0e1a\u0e49\u0e32\u0e19\u0e2b\u0e19\u0e2d\u0e07\u0e01\u0e01'},
#  {'Coordinate': [98.86231753368664, 8.09133880067675],
#   'Village': u'\u0e1a\u0e49\u0e32\u0e19\u0e44\u0e2a\u0e44\u0e17\u0e22'}]

# %%
for vill in village_list:
    name = json.dumps(vill['Village'], ensure_ascii=False)
    lng,lat = vill['Coordinate']
    print '(%.6f, %.6f), %s ' % (lat, lng, name)
# Out:
# (8.108529, 98.873204), "บ้านหนองกก"
# (8.091339, 98.862318), "บ้านไสไทย"
# (8.085012, 98.877750), "บ้านคลองจิหลาด"
# (8.058784, 98.895002), "บ้านคลองหิน"
# (8.040683, 98.860520), "บ้านอ่าวน้ำเมา"
# (8.028927, 98.871414), "บ้านแหลมโพธิ์"

# %%
keys = [
        "AIzaSyA6zubCrlHlZWT2joBJGJLJiM6vdYr6oEM",
        "AIzaSyCDGjA_AHTLlH1oknEXQo7REWZTROa7BiE",
        "AIzaSyA5mWEWwtPokDUv2lNulBQVUlJ72kdtSMQ",
        "AIzaSyCJkRo1CosMif2G6nzT1_9zeI6BJaTUJTA",
        "AIzaSyCDGjA_AHTLlH1oknEXQo7REWZTROa7BiE",
        "AIzaSyDlLnmGz8Gz2G-y1zC7dn5GJRJC3t4tbP4",
        "AIzaSyDdcR18EiXRHIGBUXN2tAaC63ktfTEHN3g",
        "AIzaSyCbs_iKDVssx0ngHqjVaGlMl12bvP-axj0",
        "AIzaSyC19LaqI24SRjvywXX34hLIfWKW07NHnGI",
        "AIzaSyCI_8p7rmObwr7uJKGwoo3oPkeBVuKHIzw",
        "AIzaSyAk5pMGnr4hv8X4ph1guOqAgNH2PUB-j14",
        "AIzaSyAIPElNOZ7sS83a-3VOe-Mw9_wUiF9sMpo",
        "AIzaSyBAqGnlTnwQnVENrVSyHWBh1AwhIZcP5Oo",
        "AIzaSyA5mWEWwtPokDUv2lNulBQVUlJ72kdtSMQ",
        "AIzaSyAXEU3aHmEHuBa80yOSrUyneL9OIWogE9Y",
        "AIzaSyDm1VQNO4-RtmNlUYYFDeGarFpIVAnn9cc",
        "AIzaSyAOmGuWFhrhDQK-8c44Ln2wBATByS-Qv-Q",
        "AIzaSyAiRjkmZz23X7IQ6KLoqfgbvlBio6mGHl4",
        "AIzaSyBiuww1q7s6lIEG4v5yauaeiw-z5YNoN60"
       ]

vill_points = get_village_points.run(province, district, subdist, village, points, keys[0])
# Out:
# get village points (metadata): 100%|██████████| 2256/2256 [01:02<00:00, 35.90it/s]
# village points: 301 points

# %%
vill_points[:3]
# Out:
# [[8.06643242265876, 98.85903343132094],
#  [8.0668064, 98.8589799],
#  [8.067342151111218, 98.85891668076893]]

# %% [markdown]
# ## GSV_loader

# %%
path = os.path.join('../GSV',province, district, subdist, village,'original')
GSV_loader.run(vill_points, path, keys)
# Out:
# loading GSV: 100%|██████████| 301/301 [15:03<00:00,  3.09s/it]
# GSV loaded

# %% [markdown]
# ### Totoal image in directory

# %%
len(os.listdir(path))
# Out:
# 1806

# %% [markdown]
# ### show sample image

# %%
sample_image = os.listdir(path)[0]
Image(os.path.join(path,sample_image),width=300)
